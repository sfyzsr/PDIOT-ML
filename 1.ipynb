# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import random

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4138131081435037538
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6951010304
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17388391859425195057
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1"
# xla_global_id: 416903419
# ]

# %%
import pandas as pd

data = pd.read_csv("./Respeck_s1732873_Climbing stairs_04-10-2022_14-29-16.csv")
data
# Out:
#          timestamp   accel_x   accel_y   accel_z     gyro_x    gyro_y  \
# 0    1664890116269  0.125977 -1.205872  0.143982  16.125000  6.187500
# 1    1664890116329  0.104004 -0.896057  0.059509  15.468750  6.812500
# 2    1664890116343  0.087402 -1.044495  0.060974   1.953125 -5.453125
# 3    1664890116389  0.058594 -0.935364  0.096619  -4.015625 -5.156250
# 4    1664890116449 -0.037842 -0.858215  0.167419  -9.843750 -7.828125
# ..             ...       ...       ...       ...        ...       ...
# 746  1664890145819 -0.163086 -0.943665  0.220398  16.031250 -1.296875
# 747  1664890145864 -0.278320 -1.401428  0.238953   9.109375 -5.828125
# 748  1664890145893 -0.255859 -1.457336  0.135925  -3.796875  2.250000
# 749  1664890145939 -0.212402 -1.308411  0.095886  -6.562500  3.781250
# 750  1664890145984 -0.212402 -1.283752 -0.051086  -8.515625 -8.296875
#
#         gyro_z sensor_type    activity_type  activity_code subject_id  notes  \
# ...

# %%
# concat all csv to one
import os
# for dirname in os.listdir("2022"):
#     for filename in os.listdir("./2022/"+dirname):
#         print(filename)
i=0
j=0
column_names = {"timestamp": float(),
"accel_x": float(),
"accel_y": float(),
"accel_z": float(),
"gyro_x": float(),
"gyro_y": float(),
"gyro_z": float(),
"sensor_type":"",
"activity_type":"",
"activity_code":"",
"subject_id":"",
"notes":"",
"recording_id":""}
respeck = pd.DataFrame(columns=column_names)
for filename in os.listdir("./2022/s1732873/"):
    # print(filename)
    path = "./2022/s1732873/"
    if(filename[0]=="R"):
        df = pd.read_csv(path+filename)
        respeck = pd.concat([respeck,df])
    if(filename[0]=="T"):
        j=j+1
respeck
# Out:
#          timestamp   accel_x   accel_y   accel_z     gyro_x    gyro_y  \
# 0    1664890116269  0.125977 -1.205872  0.143982  16.125000  6.187500
# 1    1664890116329  0.104004 -0.896057  0.059509  15.468750  6.812500
# 2    1664890116343  0.087402 -1.044495  0.060974   1.953125 -5.453125
# 3    1664890116389  0.058594 -0.935364  0.096619  -4.015625 -5.156250
# 4    1664890116449 -0.037842 -0.858215  0.167419  -9.843750 -7.828125
# ..             ...       ...       ...       ...        ...       ...
# 745  1664890294828 -0.077637 -0.812317  0.342468   9.671875 -8.468750
# 746  1664890294831 -0.063965 -0.982971  0.312927   1.625000  1.937500
# 747  1664890294874 -0.022949 -0.874085  0.496033  -0.718750  0.546875
# 748  1664890294934 -0.083740 -1.089417  0.381775  -1.015625 -1.562500
# 749  1664890294965 -0.191406 -1.158997  0.644714  -8.578125 -3.328125
#
#         gyro_z sensor_type            activity_type activity_code subject_id  \
# ...

# %%
# label the motion to digits

activites = respeck.loc[0,"activity_type"]
labelDf=pd.DataFrame({'activity_type':activites, 'label':range(len(activites))})
new = pd.merge(respeck, labelDf, how='inner', on = 'activity_type')
new.reset_index()
new.drop(columns=['sensor_type', 'activity_code','subject_id','notes','recording_id'], axis=1, inplace=True)
new['label'] = pd.to_numeric(new['label'])
# store in feather
new.to_feather("respeck.feather")
new
# Out:
#            timestamp   accel_x   accel_y   accel_z     gyro_x    gyro_y  \
# 0      1664890116269  0.125977 -1.205872  0.143982  16.125000  6.187500
# 1      1664890116329  0.104004 -0.896057  0.059509  15.468750  6.812500
# 2      1664890116343  0.087402 -1.044495  0.060974   1.953125 -5.453125
# 3      1664890116389  0.058594 -0.935364  0.096619  -4.015625 -5.156250
# 4      1664890116449 -0.037842 -0.858215  0.167419  -9.843750 -7.828125
# ...              ...       ...       ...       ...        ...       ...
# 10508  1664890294828 -0.077637 -0.812317  0.342468   9.671875 -8.468750
# 10509  1664890294831 -0.063965 -0.982971  0.312927   1.625000  1.937500
# 10510  1664890294874 -0.022949 -0.874085  0.496033  -0.718750  0.546875
# 10511  1664890294934 -0.083740 -1.089417  0.381775  -1.015625 -1.562500
# 10512  1664890294965 -0.191406 -1.158997  0.644714  -8.578125 -3.328125
#
#           gyro_z            activity_type  label
# 0       9.515625          Climbing stairs      0
# ...

# %%
r = pd.read_feather("respeck.feather")

batchSize = 32

labels = r.pop('label')
labels = labels.values.astype(float)

r.drop(columns=['timestamp','activity_type'], axis=1, inplace=True)
r = r.values.astype(float)

dataset = tf.data.Dataset.from_tensor_slices((r, labels))
for feat, targ in dataset.take(5):
  print ('Features: {}, Target: {}'.format(feat, targ))
  # print(feat.shape)
train_dataset = dataset.shuffle(len(r)).batch(32)
print(train_dataset)
# Out:
# Features: [ 0.12597656 -1.2058716   0.14398193 16.125       6.1875      9.515625  ], Target: 0.0
# Features: [ 0.10400391 -0.8960571   0.05950928 15.46875     6.8125     18.0625    ], Target: 0.0
# Features: [ 0.08740234 -1.0444946   0.06097412  1.953125   -5.453125   15.625     ], Target: 0.0
# Features: [ 0.05859375 -0.93536377  0.09661865 -4.015625   -5.15625    10.71875   ], Target: 0.0
# Features: [-0.0378418  -0.85821533  0.16741943 -9.84375    -7.828125    9.671875  ], Target: 0.0
# <BatchDataset element_spec=(TensorSpec(shape=(None, 6), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>

# %%
def get_compiled_model():
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
  ])

  model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model
with tf.device("gpu:0"):
  model = get_compiled_model()
  model.fit(train_dataset, epochs=2)
  model.save("my_model")
# Out:
# Epoch 1/2
# 329/329 [==============================] - 8s 12ms/step - loss: -91.3400 - accuracy: 0.0731
# Epoch 2/2
# 329/329 [==============================] - 4s 12ms/step - loss: -997.9175 - accuracy: 0.0714
# INFO:tensorflow:Assets written to: my_model\assets

# %%
reconstructed_model = keras.models.load_model("my_model")
print(type(reconstructed_model))
# Out:
# <class 'keras.engine.sequential.Sequential'>

# %%
test_accuracy = tf.keras.metrics.Accuracy()
for (x, y) in train_dataset:
    # training=False is needed only if there are layers with different
    # behavior during training versus inference (e.g. Dropout).
    # print(x.batch(1))
    # logits = model(x, training=False)
    logits = reconstructed_model(x, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y)
print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 7.144%
