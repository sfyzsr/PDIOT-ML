# %%
import numpy as np
import pandas as pd
import os

# %%
respeck = pd.DataFrame()
thingy = pd.DataFrame()
count = 0
for dirname in os.listdir("2022"):
    for filename in os.listdir("./2022/"+dirname):
        path = "./2022/"+dirname+"/"+filename
        if(filename[0]=="R"):
            df = pd.read_csv(path)
            respeck = pd.concat([respeck,df])
        if(filename[0]=="T"):
            df = pd.read_csv(path)
            thingy = pd.concat([thingy,df])
        count=count+1
        if(count%200==0):
            print(count)
    
respeck.shape
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# (832644, 13)

# %%
respeck.drop(columns=['sensor_type','notes','recording_id'], axis=1, inplace=True)

# %%
respeck
# Out:
#         timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0    1.664890e+12  0.125977 -1.205872  0.143982  16.125000   6.187500
# 1    1.664890e+12  0.104004 -0.896057  0.059509  15.468750   6.812500
# 2    1.664890e+12  0.087402 -1.044495  0.060974   1.953125  -5.453125
# 3    1.664890e+12  0.058594 -0.935364  0.096619  -4.015625  -5.156250
# 4    1.664890e+12 -0.037842 -0.858215  0.167419  -9.843750  -7.828125
# ..            ...       ...       ...       ...        ...        ...
# 745  1.664892e+12  0.297119 -0.773499  0.205994  54.359375 -23.093750
# 746  1.664892e+12  0.097412 -0.588928  0.104431  39.812500 -10.609375
# 747  1.664892e+12 -0.062744 -0.577698 -0.086975   6.156250 -14.250000
# 748  1.664892e+12 -0.207764 -0.866516  0.027771 -10.062500 -15.343750
# 749  1.664892e+12 -0.078369 -1.042786  0.085388  -8.734375 -13.890625
#
#         gyro_z            activity_type  activity_code subject_id
# ...

# %%
respeck=respeck.reset_index(drop=True)
respeck
# Out:
#            timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0       1.664890e+12  0.125977 -1.205872  0.143982  16.125000   6.187500
# 1       1.664890e+12  0.104004 -0.896057  0.059509  15.468750   6.812500
# 2       1.664890e+12  0.087402 -1.044495  0.060974   1.953125  -5.453125
# 3       1.664890e+12  0.058594 -0.935364  0.096619  -4.015625  -5.156250
# 4       1.664890e+12 -0.037842 -0.858215  0.167419  -9.843750  -7.828125
# ...              ...       ...       ...       ...        ...        ...
# 832639  1.664892e+12  0.297119 -0.773499  0.205994  54.359375 -23.093750
# 832640  1.664892e+12  0.097412 -0.588928  0.104431  39.812500 -10.609375
# 832641  1.664892e+12 -0.062744 -0.577698 -0.086975   6.156250 -14.250000
# 832642  1.664892e+12 -0.207764 -0.866516  0.027771 -10.062500 -15.343750
# 832643  1.664892e+12 -0.078369 -1.042786  0.085388  -8.734375 -13.890625
#
#            gyro_z            activity_type  activity_code subject_id
# ...

# %%
respeck.to_feather("respeck.feather")

# %%
thingy
# Out:
#         timestamp   accel_x   accel_y   accel_z    gyro_x     gyro_y  \
# 0    1.664544e+12 -0.903320  0.254883 -0.069336  -30.6250   34.28125
# 1    1.664544e+12 -0.942383  0.306641  0.042969  -33.3125   54.96875
# 2    1.664544e+12 -1.070312  0.260742  0.077148    0.5000   41.25000
# 3    1.664544e+12 -1.277344  0.313477 -0.056641    6.1250   19.93750
# 4    1.664544e+12 -1.381836  0.245117 -0.311523  -27.3125    5.34375
# ..            ...       ...       ...       ...       ...        ...
# 745  1.664892e+12 -0.866211 -0.039062  0.042969    4.6875 -114.62500
# 746  1.664892e+12 -0.341797  0.122070 -0.123047   79.5000  -86.87500
# 747  1.664892e+12  0.120117  0.081055  0.121094  127.0000  -72.34375
# 748  1.664892e+12 -0.139648  0.122070  0.294922   97.7500   30.31250
# 749  1.664892e+12 -0.136719  0.063477  0.600586   54.5000  144.21875
#
#        gyro_z  mag_x  mag_y  mag_z sensor_type            activity_type  \
# ...

# %%
thingy.drop(columns=['sensor_type','notes','recording_id'], axis=1, inplace=True)
thingy
# Out:
#         timestamp   accel_x   accel_y   accel_z    gyro_x     gyro_y  \
# 0    1.664544e+12 -0.903320  0.254883 -0.069336  -30.6250   34.28125
# 1    1.664544e+12 -0.942383  0.306641  0.042969  -33.3125   54.96875
# 2    1.664544e+12 -1.070312  0.260742  0.077148    0.5000   41.25000
# 3    1.664544e+12 -1.277344  0.313477 -0.056641    6.1250   19.93750
# 4    1.664544e+12 -1.381836  0.245117 -0.311523  -27.3125    5.34375
# ..            ...       ...       ...       ...       ...        ...
# 745  1.664892e+12 -0.866211 -0.039062  0.042969    4.6875 -114.62500
# 746  1.664892e+12 -0.341797  0.122070 -0.123047   79.5000  -86.87500
# 747  1.664892e+12  0.120117  0.081055  0.121094  127.0000  -72.34375
# 748  1.664892e+12 -0.139648  0.122070  0.294922   97.7500   30.31250
# 749  1.664892e+12 -0.136719  0.063477  0.600586   54.5000  144.21875
#
#        gyro_z  mag_x  mag_y  mag_z            activity_type  activity_code  \
# ...

# %%
thingy = thingy.reset_index(drop=True)
thingy.to_feather("thingy.feather")
